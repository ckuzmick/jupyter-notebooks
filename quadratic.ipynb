# %%
from matplotlib import pyplot as plt
import numpy as np

data = [(0.05, 0.51), (0.1, 0.72), (0.16, 1.101), (0.2275, 1.25), (0.295, 1.44)]

xcords, ycords = zip(*data)

x = np.linspace(.25, 1.75)
y = 0.125 * (x ** 2) + .02

plt.plot(x, y)
plt.scatter(ycords, xcords)
plt.show()
